# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Independent variable
x= df[['total_bill']].values
# Dependent variable
y =df['tip'].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x, y)
print("✅ Linear Regression Model Trained")
# Out:
# ✅ Linear Regression Model Trained

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=3)  
X_poly = poly_reg.fit_transform(x)
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y)
print("✅ Polynomial Regression Model Trained")
# Out:
# ✅ Polynomial Regression Model Trained

# %%
plt.scatter(x, y, color='red')
plt.plot(x, lin_reg.predict(x), color='blue')
plt.title("Tip Prediction (Linear Regression)")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
X_grid = np.arange(x.min(),x.max(), 0.1).reshape(-1, 1)
plt.scatter(x, y, color='red')
plt.plot(
    X_grid,
    lin_reg_poly.predict(poly_reg.transform(X_grid)),
    color='blue'
)
plt.title("Tip Prediction (Polynomial Regression)")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
linear_pred = lin_reg.predict([[25]])
poly_pred = lin_reg_poly.predict(poly_reg.transform([[25]]))
print("Linear Regression Prediction:", linear_pred)
print("Polynomial Regression Prediction:", poly_pred)
# Out:
# Linear Regression Prediction: [3.54588255]
# Polynomial Regression Prediction: [3.50832555]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_pred_linear = lin_reg.predict(x)
print("Linear Regression Metrics")
print("R2 Score:", r2_score(y, y_pred_linear))
print("MAE:", mean_absolute_error(y, y_pred_linear))
print("MSE:", mean_squared_error(y, y_pred_linear))
# Out:
# Linear Regression Metrics
# R2 Score: 0.45661658635167657
# MAE: 0.7458253894586339
# MSE: 1.036019442011377

# %%
y_pred_poly = lin_reg_poly.predict(poly_reg.transform(x))
print("Polynomial Regression Metrics")
print("R2 Score:", r2_score(y, y_pred_poly))
print("MAE:", mean_absolute_error(y, y_pred_poly))
print("MSE:", mean_squared_error(y, y_pred_poly))
# Out:
# Polynomial Regression Metrics
# R2 Score: 0.4728729406559252
# MAE: 0.733957841660296
# MSE: 1.005024938512735
